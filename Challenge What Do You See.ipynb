# %% [markdown]
# # Challenge - What Do You See?
#
#  Estimated Time: 3-4 hours
#
# Let's go out into the world and generate some beautiful visuals. Pick a data source from this aggregation, load the data into a pandas data frame, and generate a series of visuals around that data using pyplot.
#
# https://github.com/Thinkful-Ed/data-201-resources/blob/master/data-sources.md
#
# Each visualization should be accompanied by 2-3 sentences describing what you think is revealed by this representation. Generate at least four different visuals, and be sure to use different types as well as the subplot functionality discussed above. And remember: clean and elegant visuals are key to telling a coherent story.
#
# Collect your images and descriptions into a shareable format. A Jupyter notebook is best, but anything you can link to is fine, including Google docs or markdown files on GitHub or gists, and share the link below.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
titanic_df = pd.read_csv('titanic.csv')

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
# Survived                   887 non-null int64
# Pclass                     887 non-null int64
# Name                       887 non-null object
# Sex                        887 non-null object
# Age                        887 non-null float64
# Siblings/Spouses Aboard    887 non-null int64
# Parents/Children Aboard    887 non-null int64
# Fare                       887 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 48.5+ KB

# %%
titanic_df['Age'].hist(bins=80, color='purple')
plt.title("Titanic Passenger Age Histogram")
plt.xlabel('Age');

# %% [markdown]
# Here we can see that majority of the passengers on Titanic were younger, between teens and thirties, with most representative groups in 20's and 30's.

# %%
plt.plot(titanic_df['Age'])
plt.ylabel('Values')
plt.title ('Age')
plt.show() ;

# %%
cereal_df = pd.read_csv('cereal.csv')

# %%
cereal_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
np.mean(titanic_df['Age'])
# Out:
# 29.471443066516347

# %%
np.median(titanic_df['Age'])
# Out:
# 28.0

# %%
import statistics

# %%
statistics.mode(titanic_df['Age'])
# Out:
# 22.0

# %%
titanic_df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
titanic_df.describe
# Out:
# <bound method NDFrame.describe of      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 5           0       3                                    Mr. James Moran
# 6           0       1                             Mr. Timothy J McCarthy
# 7           0       3                      Master. Gosta Leonard Palsson
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10          1       3                     Miss. Marguerite Rut Sandstrom
# ...

# %%
titanic_df.shape
# Out:
# (887, 8)

# %%
titanic_df.isnull()
# Out:
#      Survived  Pclass   Name    Sex    Age  Siblings/Spouses Aboard  \
# 0       False   False  False  False  False                    False
# 1       False   False  False  False  False                    False
# 2       False   False  False  False  False                    False
# 3       False   False  False  False  False                    False
# 4       False   False  False  False  False                    False
# 5       False   False  False  False  False                    False
# 6       False   False  False  False  False                    False
# 7       False   False  False  False  False                    False
# 8       False   False  False  False  False                    False
# 9       False   False  False  False  False                    False
# 10      False   False  False  False  False                    False
# 11      False   False  False  False  False                    False
# 12      False   False  False  False  False                    False
# ...

# %%
titanic_df[['Sex']]
# Out:
#         Sex
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# 5      male
# 6      male
# 7      male
# 8    female
# 9    female
# 10   female
# 11   female
# 12     male
# 13     male
# 14   female
# 15   female
# 16     male
# 17     male
# 18   female
# 19   female
# 20     male
# 21     male
# 22   female
# 23     male
# 24   female
# 25   female
# 26     male
# 27     male
# 28   female
# 29     male
# ..      ...
# 857    male
# 858  female
# 859  female
# 860    male
# 861  female
# 862  female
# 863    male
# 864    male
# 865    male
# 866    male
# 867  female
# 868    male
# 869    male
# 870  female
# 871  female
# 872    male
# 873    male
# 874    male
# 875  female
# 876  female
# 877    male
# 878  female
# 879    male
# 880    male
# 881  female
# 882    male
# 883  female
# 884  female
# 885    male
# 886    male
#
# [887 rows x 1 columns]

# %%
titanic_df.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 857      male
# 858    female
# 859    female
# 860      male
# 861    female
# 862    female
# 863      male
# 864      male
# 865      male
# 866      male
# 867    female
# 868      male
# 869      male
# 870    female
# 871    female
# 872      male
# 873      male
# 874      male
# 875    female
# 876    female
# 877      male
# 878    female
# 879      male
# 880      male
# 881    female
# 882      male
# 883    female
# 884    female
# 885      male
# 886      male
# ...

# %%
titanic_df.Sex.describe()
# Out:
# count      887
# unique       2
# top       male
# freq       573
# Name: Sex, dtype: object

# %%
titanic_df.Sex.value_counts()
# Out:
# male      573
# female    314
# Name: Sex, dtype: int64

# %%
my_demo = ['Sex', 'Age', 'Survived']

# %%
titanic_df[my_demo].head()
# Out:
#       Sex   Age  Survived
# 0    male  22.0         0
# 1  female  38.0         1
# 2  female  26.0         1
# 3  female  35.0         1
# 4    male  35.0         0

# %%
titanic_df.Survived=='0'
titanic_df[titanic_df.Survived=='0'].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-c99590d707ed> in <module>
# ----> 1 titanic_df.Survived=='0'
#       2 titanic_df[titanic_df.Survived=='0'].head()
#
# c:\users\ira\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# c:\users\ira\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1167                     result = method(y)
#    1168                 if result is NotImplemented:
# -> 1169                     raise TypeError("invalid type comparison")
#    1170             else:
# ...

# %%
titanic_df[['Survived']]
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# 5           0
# 6           0
# 7           0
# 8           1
# 9           1
# 10          1
# 11          1
# 12          0
# 13          0
# 14          0
# 15          1
# 16          0
# 17          1
# 18          0
# 19          1
# 20          0
# 21          1
# 22          1
# 23          1
# 24          0
# 25          1
# 26          0
# 27          0
# 28          1
# 29          0
# ..        ...
# 857         0
# 858         1
# 859         0
# 860         0
# 861         1
# 862         1
# 863         0
# 864         0
# 865         1
# 866         0
# 867         1
# 868         0
# 869         0
# 870         1
# 871         1
# 872         0
# 873         0
# 874         0
# 875         1
# 876         1
# 877         0
# 878         0
# 879         0
# 880         0
# 881         0
# 882         0
# 883         1
# 884         0
# 885         1
# 886         0
#
# ...

# %%
titanic_df.Survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 857    0
# 858    1
# 859    0
# 860    0
# 861    1
# 862    1
# 863    0
# 864    0
# 865    1
# 866    0
# 867    1
# 868    0
# 869    0
# 870    1
# 871    1
# 872    0
# 873    0
# 874    0
# 875    1
# 876    1
# 877    0
# 878    0
# 879    0
# 880    0
# 881    0
# 882    0
# 883    1
# 884    0
# 885    1
# 886    0
# Name: Survived, Length: 887, dtype: int64

# %%
lived_df = titanic_df[['Sex', 'Age', 'Survived']]
lived_df[titanic_df.Sex=='male'].sort_values(by='Age', ascending = True)
# Out:
#       Sex    Age  Survived
# 799  male   0.42         1
# 751  male   0.67         1
# 827  male   0.83         1
# 77   male   0.83         1
# 303  male   0.92         1
# 163  male   1.00         0
# 823  male   1.00         1
# 384  male   1.00         0
# 182  male   1.00         1
# 784  male   1.00         1
# 820  male   2.00         0
# 7    male   2.00         0
# 16   male   2.00         0
# 338  male   2.00         1
# 346  male   3.00         1
# 405  male   3.00         1
# 192  male   3.00         1
# 259  male   3.00         1
# 706  male   4.00         1
# 865  male   4.00         1
# 62   male   4.00         0
# 846  male   4.00         0
# 170  male   4.00         0
# 442  male   4.00         1
# 175  male   5.00         0
# 158  male   5.00         0
# 747  male   6.00         1
# 64   male   7.00         1
# 49   male   7.00         0
# 276  male   7.00         0
# ..    ...    ...       ...
# 656  male  58.00         0
# 484  male  58.00         0
# ...

# %%
new_df = titanic_df[['Sex', 'Age', 'Survived']]
new_df[titanic_df.Sex=='female'].sort_values(by='Age', ascending = True)
# Out:
#         Sex    Age  Survived
# 641  female   0.75         1
# 466  female   0.75         1
# 379  female   1.00         1
# 171  female   1.00         1
# 476  female   2.00         1
# 639  female   2.00         0
# 204  female   2.00         0
# 527  female   2.00         1
# 118  female   2.00         0
# 295  female   2.00         0
# 127  female   2.00         1
# 407  female   3.00         0
# 372  female   3.00         0
# 42   female   3.00         1
# 183  female   4.00         1
# 615  female   4.00         1
# 10   female   4.00         1
# 688  female   4.00         1
# 746  female   4.00         1
# 445  female   5.00         1
# 773  female   5.00         1
# 57   female   5.00         1
# 232  female   5.00         1
# 716  female   6.00         1
# 809  female   6.00         0
# 532  female   7.00         1
# 884  female   7.00         0
# 482  female   8.00         0
# 179  female   8.00         0
# 236  female   8.00         1
# ..      ...    ...       ...
# ...

# %% [markdown]
# # Assigment: "Challenge--What Do You See?"
# ## Visual Analysis of the Titanic Data Set
# ### Who were the people on board of the ship?
#
# By: Ira Yavorska
#
# Data: Titanic Data Set http://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
#
# Objective: Chose a data set and generate a series of visuals around that data using pyplot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing my dataset:
titanic_df = pd.read_csv('titanic.csv')

# %%
#set up plot prameters
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size' : 22})

# %% [markdown]
# First I want to visually analyze Titanic passenger demographics, I am especially interested in sex and age.

# %%
titanic_df.Sex.value_counts().plot(kind='bar', title='Titanic Passengers Demographics')
plt.xticks(rotation=360)
plt.xlabel('Sex')
plt.ylabel('Count') ;

# %% [markdown]
# Interesting, looks like there were almost twice as many males on the ship as there were females. I wonder what was the age distribution and if there was any connection between age or sex and survival rate. First I will review histogram of the passengers age, see figure bellow:

# %%
titanic_df.Age.hist();

# %% [markdown]
# It appears that most of the passengers were between twenties and thirties, median age analysis of the group is presented in the graphic bellow:

# %%
titanic_df.groupby('Sex').Age.median().plot(kind='bar', title="Median Age of Titanic Passengers")
plt.xticks(rotation=360)
plt.xlabel('Sex')
plt.ylabel('Age') ;

# %% [markdown]
# Knowing which of the pasengers survived, I will compare number of male vs female survivors.
#
# Based on the graphic bellow, vast majority of male passengers deseased:

# %%
titanic_df.groupby('Survived').Sex.value_counts().plot(kind='bar', title="Deseased vs. Survived Titanic Passengers")
plt.xlabel('Deseased vs. Survived')
plt.ylabel('Count')
plt.show();

# %%
plt.figure(figsize=(15, 8))

plt.subplot(1,2,2)
new_df[titanic_df.Sex=='female'].Survived.value_counts().plot(kind='bar')
plt.ylim([0.0, 550])
plt.ylabel('Count')
plt.title('Female Survived vs. Deceased')

plt.subplot(1,2,1)
new_df[titanic_df.Sex=='male'].Survived.value_counts().plot(kind='bar')
plt.ylim([0.0, 550])
plt.ylabel('Count')
plt.title('Male Deceased vs. Survived')
plt.show() ;

# %%
plt.scatter(x=titanic_df['Age'], y=titanic_df['Fare'])
plt.show() ;

# %%
x = new_df[titanic_df.Sex=='male'].Age
y = new_df[titanic_df.Sex=='female'].Age
plt.hist(x, color='blue', bins=np.arange(0, 80), alpha=.2) 
plt.hist(y, color='red', bins=np.arange(0, 80), alpha=.2)

plt.title('Male vs. Female Age Histogram')
plt.xlabel('Passenger Age')
plt.show() ;
